# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

base_credit = pd.read_csv("credit.csv")
print(base_credit.head(10))
print(base_credit.describe())
print(base_credit[base_credit["person_age"] >= 144])
sns.countplot(x=base_credit["person_age"])
np.unique(base_credit["person_age"])
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
# 5          21           9900                   OWN                2.0
# 6          26          77100                  RENT                8.0
# 7          24          78956                  RENT                5.0
# 8          24          83000                  RENT                8.0
# 9          21          10000                   OWN                6.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# ...

# %%
plt.hist(x = base_credit['person_age']);

# %%
plt.hist(x = base_credit['person_income']);

# %%
grafico = px.scatter_matrix(base_credit, dimensions=['person_age', 'person_income'])
grafico.show()
# Out:
# <div>                            <div id="38ad169f-2ab0-4791-a586-b3709bf98398" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38ad169f-2ab0-4791-a586-b3709bf98398")) {                    Plotly.newPlot(                        "38ad169f-2ab0-4791-a586-b3709bf98398",                        [{"dimensions":[{"axis":{"matches":true},"label":"person_age","values":[22,21,25,23,24,21,26,24,24,21,22,21,23,26,23,23,23,23,23,24,25,25,22,24,22,24,21,23,24,21,21,25,26,25,26,21,22,24,25,23,26,24,26,23,26,26,25,26,22,26,24,23,23,23,25,26,26,23,25,24,21,22,26,25,22,22,26,25,24,25,25,22,21,23,26,26,22,21,22,24,24,144,25,26,26,22,23,24,21,22,22,26,24,24,23,23,24,22,25,24,26,25,26,25,23,22,25,21,24,25,24,26,25,26,24,24,23,22,26,25,22,25,21,25,26,23,26,22,23,25,24,23
# ...

# %%
base_credit.loc[base_credit['person_age'] > 100]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 81            144         250000                  RENT                4.0
# 183           144         200000              MORTGAGE                4.0
# 575           123          80004                  RENT                2.0
# 747           123          78000                  RENT                7.0
# 32297         144        6000000              MORTGAGE               12.0
#
#       loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 81        VENTURE          C       4800          13.57            0
# 183     EDUCATION          B       6000          11.86            0
# 575     EDUCATION          B      20400          10.25            0
# 747       VENTURE          B      20000            NaN            0
# 32297    PERSONAL          C       5000          12.73            0
#
#        loan_percent_income cb_person_default_on_file  \
# 81                    0.02                         N
# ...

# %%
base_credito2 = base_credit.drop(base_credit[base_credit['person_age'] > 125].index)
base_credito2
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
base_credito2.loc[base_credito2['person_age'] > 100]
# Out:
#      person_age  person_income person_home_ownership  person_emp_length  \
# 575         123          80004                  RENT                2.0
# 747         123          78000                  RENT                7.0
#
#     loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 575   EDUCATION          B      20400          10.25            0
# 747     VENTURE          B      20000            NaN            0
#
#      loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 575                 0.25                         N                           3
# 747                 0.26                         N                           4

# %%
type(base_credito2)
# Out:
# pandas.core.frame.DataFrame

# %%
base_credito2['person_age'].mean()
# Out:
# 27.723893425010743

# %%
base_credit['person_age'][base_credit['person_age'] > 0].mean()
# Out:
# 27.73459992019889

# %%
meses = ['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out','nov']
temperatura = [23, 24.1, 26.1, 27.8, 29.4, 21.2, 32.1, 12.3, 10.4, 24.3,25.6]
plt.suptitle('Temperatura media mensal')
plt.plot(meses, temperatura)
